# %% [markdown]
# <center><h1>COL341 Spring 2023<br>Assignment 4: Neural Network</h1>
#  <h2>Amaiya Singhal</h2>
#  </center>

# %% [markdown]
# As mentioned in the assigment, some of the data loading and training code is inspired from here - https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim

# %%
# Set seeds for reproducibility
seed = 42
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Load CIFAR 10 data

# %%
# Define data augmentation for train
train_transform = transform = transforms.Compose([
        transforms.RandomHorizontalFlip(), # augementation
        transforms.RandomRotation(10), # augmentation
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

val_transform =  transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# Get train and test dataloaders
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=train_transform)

valset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=val_transform)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(f"Training data shape: {len(trainset)}")
print(f"Test data shape: {len(valset)}")
# Out:
# Training data shape: 50000
# Test data shape: 10000

# %% [markdown]
# # Plot random training set examples

# %%
def imshow(img):
    img = img / 2 + 0.5 # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis("off")
    plt.show()

# get some random training images
n = 4
dataiter = np.random.choice(len(trainset), replace=False, size=n)
images, labels = [trainset[i][0] for i in dataiter], [trainset[i][1] for i in dataiter]

# show images
imshow(torchvision.utils.make_grid(images, padding=3))
# print labels
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(n)))
# Out:
# horse ship  plane frog

# %% [markdown]
# # 4 Part 2: Implement a PyTorch-based Solution

# %% [markdown]
# ## Model
#
# Pytorch implementation of the model as requested in part 1 of the assignment -
# - CONV1: Kernel size (3 × 3), In channels 3, Out channels 32.
# - POOL1: Kernel size (2 × 2).
# - CONV2: Kernel size (5 × 5), In channels 32, Out channels 64.
# - POOL2: Kernel size (2 × 2).
# - CONV3: Kernel size (3 × 3), In channels 64, Out channels 64.
# - FC1: Fully connected layer (also known as Linear layer) with 64 output neurons.
# - FC2: Fully connected layer with 10 output neurons.
#
# Using ReLU as the activation function for all layers apart from the max-pooling layers, and the FC2
# layer.

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.fc1 = nn.Linear(64*3*3, 64)
        self.fc2 = nn.Linear(64, 10)
        self.pool = nn.MaxPool2d(2, 2)
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# # Experiments
#
# Here I define a global experiments class that can run any hyperparameter tuning experiment independently by just providing a config file (python dictionary) that should have the following structure -
# ```
# config = {
#             "epochs": 20,                    # defines number of epochs
#             "lr": 0.1,                       # defines learning rate
#             "batch_size": 32,                # defines batch size
#             "optimizer": "adam",             # defines optimizer, 'adam' or 'sgd'
#             "criterion": "cross_entropy",    # defines loss function, 'cross_entropy' or 'kl_divergence'
#             "lr_scheduler": False            # True or False, to use MultiStepLR scheduler or not
#          }
# ```

# %%
class Experiment:
    """
    Runs a training experiment, given an appropriate config dictionary.
    Allows repeatable experiments by just changing a few hyperparameters.
    """
    def __init__(self, config):
        """
        Takes a config as input that contains the keys:
        epochs: Specifies number of epochs to train the model for (default 20)
        lr: Learning rate for the optimizer (default 0.001)
        batch_size: Number of images to comprise a minibatch (default 32)
        optimizer: Choose from 'adam' or 'sgd'
        criterion: Choose from 'cross_entropy' or 'kl_divergence'
        lr_scheduler: True or False value to specify usage of the MultiStepLR lr scheduler.
        """
        self.config = config
        self.device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
        self.epochs = config.get("epochs", 20)
        self.lr = config.get("lr", 0.001)
        self.batch_size = config.get("batch_size", 32)
        self.model = CNN().to(self.device)
    
        # Define optimizer
        opt = config.get("optimizer", "adam")
        if opt.lower() == "adam":
            self.config["optimizer"] = "adam"
            self.optimizer = optim.Adam(self.model.parameters(), lr = self.lr)
        else:
            self.config["optimizer"] = "sgd"
            self.optimizer = optim.SGD(self.model.parameters(), lr = self.lr)
            
        # Define criterion
        crit = config.get("criterion", "cross_entropy")
        if crit.lower() == "cross_entropy":
            self.config["criterion"] = "cross_entropy"
            self.criterion = nn.CrossEntropyLoss()
        else:
            self.config["criterion"] = "kl_divergence"
            self.criterion = nn.KLDivLoss(reduction="batchmean")
        
        # Define train and val dataloaders
        self.trainloader = torch.utils.data.DataLoader(trainset, 
                                                       batch_size=self.batch_size, 
                                                       shuffle=True, 
                                                       num_workers=0)
        self.valloader = torch.utils.data.DataLoader(valset, 
                                                batch_size=self.batch_size, 
                                                shuffle=False, 
                                                num_workers=0)
        
        # Define learning rate scheduler
        lr_scheduler = config.get("lr_scheduler", False)
        if lr_scheduler:
            self.config["lr_scheduler"] = "MultiStepLR"
            self.scheduler = optim.lr_scheduler.MultiStepLR(self.optimizer, 
                                        milestones=[10, 15, 20], # List of epoch indices
                                        gamma =0.5)
        else:
            self.config["lr_scheduler"] = False
            self.scheduler = None
            
        self.train_losses, self.val_losses = [], []
        self.train_acc, self.val_acc = [], []
        self.val_classwise_accuracy = {classname: [0,0] for classname in classes}
                
    def get_classwise_val_accuracy(self):
        print(f"Classwise accuracies on validation set after epoch {self.epochs} -")
        for classname, counts in self.val_classwise_accuracy.items():
            accuracy = 100 * float(counts[0]) / counts[1]
            print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
        
    def _run_validation(self, cur_epoch):
        with torch.no_grad():
            running_val_loss, val_correct = 0.0, 0
            for val_data in self.valloader:
                val_inputs, val_labels = val_data[0].to(self.device), val_data[1].to(self.device)
                val_outputs = self.model(val_inputs)
                
                # KL divergence loss needs preds and targets as probability distributions
                if self.config["criterion"] == "kl_divergence":
                    val_loss = self.criterion(F.log_softmax(val_outputs, dim=1), 
                                              F.one_hot(val_labels, num_classes=len(classes)).float())
                else:
                    val_loss = self.criterion(val_outputs, val_labels)
                    
                running_val_loss += val_loss.item()
                val_preds = torch.argmax(val_outputs, 1)
                val_correct += (val_preds == val_labels).sum().item()

                # Save classwise accuracy for last epoch
                if cur_epoch == self.epochs:
                    for l, p in zip(val_labels, val_preds):
                        if l == p:
                            self.val_classwise_accuracy[classes[l]][0] += 1
                        self.val_classwise_accuracy[classes[l]][1] += 1
                        
        return running_val_loss/len(self.valloader), val_correct/len(valset)
    
    def plot_graphs(self):
        fig = plt.figure(figsize=(15, 5))
        fig.suptitle(f"LR = {self.lr}, Optimizer = {self.config['optimizer']}", fontsize=16)
        ax0 = fig.add_subplot(121, title="Loss")
        ax0.plot(np.arange(len(self.train_losses)), self.train_losses, 'bo-', label = "Train")
        ax0.plot(np.arange(len(self.val_losses)), self.val_losses, 'ro-', label = "Val")
        ax0.set_xlabel("Epoch")
        ax0.set_ylabel("Loss value")
        ax0.legend()
        
        ax1 = fig.add_subplot(122, title="Accuracy")
        ax1.plot(np.arange(len(self.train_acc)), self.train_acc, 'bo-', label = "Train")
        ax1.plot(np.arange(len(self.val_acc)), self.val_acc, 'ro-', label = "Val")
        ax1.set_xlabel("Epoch")
        ax1.set_ylabel("Accuracy (%)")
        ax1.legend()
        plt.show()
        
                
    def run_experiment(self):
        print("Running experiment with -")
        for key in self.config:
            print(f"  {key}: {self.config[key]}")
        print("----------------------------")
        
        for epoch in range(self.epochs):
            running_loss, running_correct = 0.0, 0
            for i, data in enumerate(self.trainloader, 0):
                inputs, labels = data[0].to(self.device), data[1].to(self.device)
                self.optimizer.zero_grad()

                outputs = self.model(inputs)
                
                # KL divergence loss needs preds and targets as probability distributions
                if self.config["criterion"] == "kl_divergence":
                    loss = self.criterion(F.log_softmax(outputs, dim=1), 
                                          F.one_hot(labels, num_classes=len(classes)).float())
                else:
                    loss = self.criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()

                running_loss += loss.item()
                preds = torch.argmax(outputs, 1)
                running_correct += (preds == labels).sum().item()
            
            if self.config["lr_scheduler"]:
                self.scheduler.step()

            train_loss, train_acc = running_loss/len(self.trainloader), running_correct/len(trainset)
            
            # Run validation after every epoch
            val_loss, val_accuracy = self._run_validation(cur_epoch = epoch+1)
            self.train_losses.append(train_loss)
            self.val_losses.append(val_loss)
            self.train_acc.append(train_acc*100)
            self.val_acc.append(val_accuracy*100)
            print(f"Epoch: {epoch+1} | Train loss: {train_loss:.3f} | Train acc: {train_acc:.3f} | Val loss: {val_loss:.3f} |  Val acc: {val_accuracy:.3f}")
            if self.config["lr_scheduler"]:
                print(f"Epoch: {epoch+1} | Learning rate: {self.optimizer.param_groups[0]['lr']}")
        print('Finished Training')

# %% [markdown]
# # 4.1.1 Learning Rate (LR)
#
# All experiments here will be run with **batch size = 32** and **epochs = 20** and **adam** optimizer.

# %% [markdown]
# ## LR = 0.001 (Adam)

# %%
exp1 = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "adam"})
exp1.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 32
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.548 | Train acc: 0.432 | Val loss: 1.300 |  Val acc: 0.526
# Epoch: 2 | Train loss: 1.213 | Train acc: 0.564 | Val loss: 1.156 |  Val acc: 0.593
# Epoch: 3 | Train loss: 1.071 | Train acc: 0.620 | Val loss: 1.046 |  Val acc: 0.636
# Epoch: 4 | Train loss: 0.993 | Train acc: 0.648 | Val loss: 0.968 |  Val acc: 0.660
# Epoch: 5 | Train loss: 0.935 | Train acc: 0.669 | Val loss: 0.944 |  Val acc: 0.674
# Epoch: 6 | Train loss: 0.889 | Train acc: 0.686 | Val loss: 0.867 |  Val acc: 0.702
# Epoch: 7 | Train loss: 0.854 | Train acc: 0.699 | Val loss: 0.860 |  Val acc: 0.700
# Epoch: 8 | Train loss: 0.822 | Train acc: 0.712 | Val loss: 0.871 |  Val acc: 0.701
# Epoch: 9 | Train loss: 0.800 | Train acc: 0.717 | Val loss: 0.828 |  Val acc: 0.713
# ...

# %%
exp1.plot_graphs()

# %%
exp1.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 70.5 %
# Accuracy for class: car   is 86.3 %
# Accuracy for class: bird  is 57.6 %
# Accuracy for class: cat   is 66.3 %
# Accuracy for class: deer  is 70.7 %
# Accuracy for class: dog   is 65.2 %
# Accuracy for class: frog  is 79.4 %
# Accuracy for class: horse is 74.1 %
# Accuracy for class: ship  is 77.7 %
# Accuracy for class: truck is 83.7 %

# %% [markdown]
# **Observation:**

# %% [markdown]
# ## LR = 0.001 (SGD)

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "sgd"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 32
#   optimizer: sgd
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 2.304 | Train acc: 0.100 | Val loss: 2.302 |  Val acc: 0.100
# Epoch: 2 | Train loss: 2.300 | Train acc: 0.117 | Val loss: 2.298 |  Val acc: 0.169
# Epoch: 3 | Train loss: 2.294 | Train acc: 0.178 | Val loss: 2.289 |  Val acc: 0.169
# Epoch: 4 | Train loss: 2.278 | Train acc: 0.162 | Val loss: 2.260 |  Val acc: 0.168
# Epoch: 5 | Train loss: 2.227 | Train acc: 0.177 | Val loss: 2.178 |  Val acc: 0.189
# Epoch: 6 | Train loss: 2.121 | Train acc: 0.217 | Val loss: 2.055 |  Val acc: 0.242
# Epoch: 7 | Train loss: 2.017 | Train acc: 0.258 | Val loss: 1.975 |  Val acc: 0.280
# Epoch: 8 | Train loss: 1.942 | Train acc: 0.292 | Val loss: 1.898 |  Val acc: 0.310
# Epoch: 9 | Train loss: 1.872 | Train acc: 0.314 | Val loss: 1.833 |  Val acc: 0.329
# ...

# %%
exp.plot_graphs()

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 48.2 %
# Accuracy for class: car   is 68.8 %
# Accuracy for class: bird  is 20.7 %
# Accuracy for class: cat   is 17.7 %
# Accuracy for class: deer  is 38.0 %
# Accuracy for class: dog   is 48.3 %
# Accuracy for class: frog  is 64.7 %
# Accuracy for class: horse is 54.9 %
# Accuracy for class: ship  is 41.0 %
# Accuracy for class: truck is 47.6 %

# %% [markdown]
# **Observation:** With SGD lr of 0.001 is too small and we can do better with increasing it. With Adam the same LR was kind of perfect.

# %% [markdown]
# ## LR = 0.1 (Adam)

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.1,
                          "batch_size": 32,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.1
#   batch_size: 32
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 5.915 | Train acc: 0.100 | Val loss: 2.321 |  Val acc: 0.100
# Epoch: 2 | Train loss: 2.315 | Train acc: 0.099 | Val loss: 2.309 |  Val acc: 0.100
# Epoch: 3 | Train loss: 2.315 | Train acc: 0.099 | Val loss: 2.310 |  Val acc: 0.100
# Epoch: 4 | Train loss: 2.316 | Train acc: 0.100 | Val loss: 2.321 |  Val acc: 0.100
# Epoch: 5 | Train loss: 2.315 | Train acc: 0.102 | Val loss: 2.314 |  Val acc: 0.100
# Epoch: 6 | Train loss: 2.316 | Train acc: 0.098 | Val loss: 2.310 |  Val acc: 0.100
# Epoch: 7 | Train loss: 2.314 | Train acc: 0.103 | Val loss: 2.307 |  Val acc: 0.100
# Epoch: 8 | Train loss: 2.315 | Train acc: 0.101 | Val loss: 2.307 |  Val acc: 0.100
# Epoch: 9 | Train loss: 2.316 | Train acc: 0.098 | Val loss: 2.321 |  Val acc: 0.100
# ...

# %%
exp.plot_graphs()

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 0.0 %
# Accuracy for class: car   is 0.0 %
# Accuracy for class: bird  is 0.0 %
# Accuracy for class: cat   is 0.0 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 0.0 %
# Accuracy for class: frog  is 0.0 %
# Accuracy for class: horse is 0.0 %
# Accuracy for class: ship  is 100.0 %
# Accuracy for class: truck is 0.0 %

# %% [markdown]
# **Observation:** LR is too large, does not converge, model not learning anything. Reduce LR.

# %% [markdown]
# ## LR = 0.1 (SGD)

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.1,
                          "batch_size": 32,
                          "optimizer": "sgd"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.1
#   batch_size: 32
#   optimizer: sgd
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.655 | Train acc: 0.392 | Val loss: 1.374 |  Val acc: 0.506
# Epoch: 2 | Train loss: 1.223 | Train acc: 0.563 | Val loss: 1.236 |  Val acc: 0.566
# Epoch: 3 | Train loss: 1.027 | Train acc: 0.638 | Val loss: 1.119 |  Val acc: 0.610
# Epoch: 4 | Train loss: 0.897 | Train acc: 0.686 | Val loss: 0.973 |  Val acc: 0.673
# Epoch: 5 | Train loss: 0.806 | Train acc: 0.717 | Val loss: 0.931 |  Val acc: 0.680
# Epoch: 6 | Train loss: 0.741 | Train acc: 0.738 | Val loss: 0.946 |  Val acc: 0.685
# Epoch: 7 | Train loss: 0.680 | Train acc: 0.761 | Val loss: 0.940 |  Val acc: 0.693
# Epoch: 8 | Train loss: 0.631 | Train acc: 0.781 | Val loss: 0.948 |  Val acc: 0.694
# Epoch: 9 | Train loss: 0.585 | Train acc: 0.793 | Val loss: 1.001 |  Val acc: 0.691
# ...

# %%
exp.plot_graphs()

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 80.0 %
# Accuracy for class: car   is 83.5 %
# Accuracy for class: bird  is 37.2 %
# Accuracy for class: cat   is 39.2 %
# Accuracy for class: deer  is 62.1 %
# Accuracy for class: dog   is 56.5 %
# Accuracy for class: frog  is 90.3 %
# Accuracy for class: horse is 70.4 %
# Accuracy for class: ship  is 78.7 %
# Accuracy for class: truck is 72.0 %

# %% [markdown]
# **Observation:** Increasing LR does lead to better convergence as expected for SGD.

# %% [markdown]
# ## LR = 0.0002 (Adam)

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 2e-4,
                          "batch_size": 32,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.0002
#   batch_size: 32
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.727 | Train acc: 0.364 | Val loss: 1.509 |  Val acc: 0.450
# Epoch: 2 | Train loss: 1.440 | Train acc: 0.476 | Val loss: 1.337 |  Val acc: 0.515
# Epoch: 3 | Train loss: 1.317 | Train acc: 0.525 | Val loss: 1.288 |  Val acc: 0.534
# Epoch: 4 | Train loss: 1.230 | Train acc: 0.562 | Val loss: 1.219 |  Val acc: 0.560
# Epoch: 5 | Train loss: 1.161 | Train acc: 0.588 | Val loss: 1.135 |  Val acc: 0.594
# Epoch: 6 | Train loss: 1.106 | Train acc: 0.609 | Val loss: 1.074 |  Val acc: 0.621
# Epoch: 7 | Train loss: 1.060 | Train acc: 0.626 | Val loss: 1.041 |  Val acc: 0.630
# Epoch: 8 | Train loss: 1.020 | Train acc: 0.641 | Val loss: 1.030 |  Val acc: 0.641
# Epoch: 9 | Train loss: 0.985 | Train acc: 0.655 | Val loss: 0.968 |  Val acc: 0.655
# ...

# %%
exp.plot_graphs()

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 80.5 %
# Accuracy for class: car   is 86.8 %
# Accuracy for class: bird  is 60.2 %
# Accuracy for class: cat   is 42.4 %
# Accuracy for class: deer  is 62.7 %
# Accuracy for class: dog   is 70.3 %
# Accuracy for class: frog  is 78.6 %
# Accuracy for class: horse is 78.1 %
# Accuracy for class: ship  is 81.9 %
# Accuracy for class: truck is 82.5 %

# %% [markdown]
# **Observation:** LR is too small, updates are slow. Both val loss and train loss still decreasing. Could do with increased LR.

# %% [markdown]
# ## LR = 0.0002 (SGD)

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 2e-4,
                          "batch_size": 32,
                          "optimizer": "sgd"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.0002
#   batch_size: 32
#   optimizer: sgd
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 2.305 | Train acc: 0.100 | Val loss: 2.304 |  Val acc: 0.100
# Epoch: 2 | Train loss: 2.304 | Train acc: 0.100 | Val loss: 2.303 |  Val acc: 0.102
# Epoch: 3 | Train loss: 2.303 | Train acc: 0.105 | Val loss: 2.302 |  Val acc: 0.112
# Epoch: 4 | Train loss: 2.301 | Train acc: 0.116 | Val loss: 2.301 |  Val acc: 0.122
# Epoch: 5 | Train loss: 2.300 | Train acc: 0.127 | Val loss: 2.299 |  Val acc: 0.131
# Epoch: 6 | Train loss: 2.298 | Train acc: 0.136 | Val loss: 2.298 |  Val acc: 0.140
# Epoch: 7 | Train loss: 2.297 | Train acc: 0.140 | Val loss: 2.296 |  Val acc: 0.141
# Epoch: 8 | Train loss: 2.295 | Train acc: 0.142 | Val loss: 2.294 |  Val acc: 0.142
# Epoch: 9 | Train loss: 2.293 | Train acc: 0.143 | Val loss: 2.291 |  Val acc: 0.149
# ...

# %%
exp.plot_graphs()

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 11.0 %
# Accuracy for class: car   is 21.2 %
# Accuracy for class: bird  is 0.0 %
# Accuracy for class: cat   is 15.4 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 1.4 %
# Accuracy for class: frog  is 32.0 %
# Accuracy for class: horse is 52.7 %
# Accuracy for class: ship  is 44.7 %
# Accuracy for class: truck is 46.0 %

# %% [markdown]
# # 4.1.2 Variation in LR
#
# Here I have chosen the learning rate scheduler to be **MultiStepLR** with the following structure -
#
# ```
# scheduler = optim.lr_scheduler.MultiStepLR(optimizer,
#                                            milestones=[10, 15, 20], # List of epoch indices
#                                            gamma = 0.5)
# ```
#
# The starting LR is chosen to be **0.001** for Adam and **0.1** for SGD. Based on experiments in part 1, it looks like the val loss stops decreasing after epoch 10, so here I will try to reduce LR from there after every 5 epochs.
#
# Experiment here will be run with **batch size = 32** and **epochs = 20**.

# %% [markdown]
# ### With Adam optimizer

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "adam",
                          "lr_scheduler": True})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 32
#   optimizer: adam
#   lr_scheduler: MultiStepLR
#   criterion: cross_entropy
# ----------------------------
# Epoch: 1 | Train loss: 1.533 | Train acc: 0.434 | Val loss: 1.247 |  Val acc: 0.553
# Epoch: 1 | Learning rate: 0.001
# Epoch: 2 | Train loss: 1.214 | Train acc: 0.564 | Val loss: 1.166 |  Val acc: 0.583
# Epoch: 2 | Learning rate: 0.001
# Epoch: 3 | Train loss: 1.094 | Train acc: 0.611 | Val loss: 1.039 |  Val acc: 0.634
# Epoch: 3 | Learning rate: 0.001
# Epoch: 4 | Train loss: 1.015 | Train acc: 0.639 | Val loss: 0.968 |  Val acc: 0.653
# Epoch: 4 | Learning rate: 0.001
# Epoch: 5 | Train loss: 0.955 | Train acc: 0.660 | Val loss: 0.948 |  Val acc: 0.660
# Epoch: 5 | Learning rate: 0.001
# Epoch: 6 | Train loss: 0.910 | Train acc: 0.680 | Val loss: 0.891 |  Val acc: 0.683
# Epoch: 6 | Learning rate: 0.001
# Epoch: 7 | Train loss: 0.876 | Train acc: 0.689 | Val loss: 0.888 |  Val acc: 0.685
# ...

# %%
exp.plot_graphs()

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 78.1 %
# Accuracy for class: car   is 88.8 %
# Accuracy for class: bird  is 66.8 %
# Accuracy for class: cat   is 53.9 %
# Accuracy for class: deer  is 74.8 %
# Accuracy for class: dog   is 69.8 %
# Accuracy for class: frog  is 82.5 %
# Accuracy for class: horse is 77.2 %
# Accuracy for class: ship  is 85.5 %
# Accuracy for class: truck is 80.8 %

# %% [markdown]
# **Observation:** As expected after 10 epochs, reducing the LR leads to better learning of the model and it is able to achieve better val accuracy as compared to the previous approaches (~0.75 compared to ~0.73). Classwise accuracies have also improved.

# %% [markdown]
# ### With SGD Optimizer
#
# Starting with LR of 0.1 for this to see the effect of SGD to learn with the same scheduler as used for Adam

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.1,
                          "batch_size": 32,
                          "optimizer": "SGD",
                          "lr_scheduler": True})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.1
#   batch_size: 32
#   optimizer: sgd
#   lr_scheduler: MultiStepLR
#   criterion: cross_entropy
# ----------------------------
# Epoch: 1 | Train loss: 1.660 | Train acc: 0.389 | Val loss: 1.473 |  Val acc: 0.475
# Epoch: 1 | Learning rate: 0.1
# Epoch: 2 | Train loss: 1.228 | Train acc: 0.564 | Val loss: 1.194 |  Val acc: 0.576
# Epoch: 2 | Learning rate: 0.1
# Epoch: 3 | Train loss: 1.031 | Train acc: 0.633 | Val loss: 1.153 |  Val acc: 0.610
# Epoch: 3 | Learning rate: 0.1
# Epoch: 4 | Train loss: 0.907 | Train acc: 0.681 | Val loss: 0.997 |  Val acc: 0.656
# Epoch: 4 | Learning rate: 0.1
# Epoch: 5 | Train loss: 0.815 | Train acc: 0.714 | Val loss: 0.951 |  Val acc: 0.681
# Epoch: 5 | Learning rate: 0.1
# Epoch: 6 | Train loss: 0.744 | Train acc: 0.739 | Val loss: 0.983 |  Val acc: 0.676
# Epoch: 6 | Learning rate: 0.1
# Epoch: 7 | Train loss: 0.688 | Train acc: 0.758 | Val loss: 0.916 |  Val acc: 0.693
# ...

# %%
exp.plot_graphs()

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 75.6 %
# Accuracy for class: car   is 84.0 %
# Accuracy for class: bird  is 59.0 %
# Accuracy for class: cat   is 53.5 %
# Accuracy for class: deer  is 67.0 %
# Accuracy for class: dog   is 64.4 %
# Accuracy for class: frog  is 79.5 %
# Accuracy for class: horse is 74.3 %
# Accuracy for class: ship  is 81.5 %
# Accuracy for class: truck is 81.4 %

# %% [markdown]
# # 4.1.3 Number of Training Epochs
#
# All experiments here will be run with **learning rate = 0.001** and **batch size = 32**.

# %% [markdown]
# ## Epochs = 5 (Adam)

# %%
exp = Experiment(config={"epochs": 5,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 5
#   lr: 0.001
#   batch_size: 32
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.546 | Train acc: 0.434 | Val loss: 1.286 |  Val acc: 0.529
# Epoch: 2 | Train loss: 1.205 | Train acc: 0.571 | Val loss: 1.136 |  Val acc: 0.599
# Epoch: 3 | Train loss: 1.069 | Train acc: 0.619 | Val loss: 1.034 |  Val acc: 0.635
# Epoch: 4 | Train loss: 0.987 | Train acc: 0.652 | Val loss: 0.993 |  Val acc: 0.652
# Epoch: 5 | Train loss: 0.931 | Train acc: 0.672 | Val loss: 0.903 |  Val acc: 0.685
# Finished Training

# %%
exp.plot_graphs()

# %% [markdown]
# ## Epochs = 5 (SGD)

# %%
exp = Experiment(config={"epochs": 5,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "sgd"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 5
#   lr: 0.001
#   batch_size: 32
#   optimizer: sgd
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 2.303 | Train acc: 0.100 | Val loss: 2.300 |  Val acc: 0.101
# Epoch: 2 | Train loss: 2.297 | Train acc: 0.115 | Val loss: 2.293 |  Val acc: 0.134
# Epoch: 3 | Train loss: 2.285 | Train acc: 0.145 | Val loss: 2.273 |  Val acc: 0.184
# Epoch: 4 | Train loss: 2.254 | Train acc: 0.199 | Val loss: 2.225 |  Val acc: 0.220
# Epoch: 5 | Train loss: 2.184 | Train acc: 0.215 | Val loss: 2.127 |  Val acc: 0.224
# Finished Training

# %%
exp.plot_graphs()

# %% [markdown]
# ## Epochs = 40 (Adam)

# %%
exp = Experiment(config={"epochs": 40,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 40
#   lr: 0.001
#   batch_size: 32
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.522 | Train acc: 0.440 | Val loss: 1.248 |  Val acc: 0.548
# Epoch: 2 | Train loss: 1.188 | Train acc: 0.574 | Val loss: 1.107 |  Val acc: 0.608
# Epoch: 3 | Train loss: 1.053 | Train acc: 0.627 | Val loss: 1.018 |  Val acc: 0.647
# Epoch: 4 | Train loss: 0.970 | Train acc: 0.657 | Val loss: 0.959 |  Val acc: 0.667
# Epoch: 5 | Train loss: 0.912 | Train acc: 0.676 | Val loss: 0.943 |  Val acc: 0.671
# Epoch: 6 | Train loss: 0.868 | Train acc: 0.695 | Val loss: 0.880 |  Val acc: 0.692
# Epoch: 7 | Train loss: 0.830 | Train acc: 0.709 | Val loss: 0.843 |  Val acc: 0.704
# Epoch: 8 | Train loss: 0.799 | Train acc: 0.719 | Val loss: 0.822 |  Val acc: 0.714
# Epoch: 9 | Train loss: 0.779 | Train acc: 0.730 | Val loss: 0.824 |  Val acc: 0.716
# ...

# %%
exp.plot_graphs()

# %% [markdown]
# **Observations:** less epochs not always enough, since the model has potential to learn more as both train and vall losses seem to be decreasing. So to early to stop training. More epochs not always preferable since training loss will continue to decrease as model starts overfitting and kind of memorizing the training set, leading to poor performance on validation and test datasets.

# %% [markdown]
# ## Epochs = 40 (SGD)

# %%
exp = Experiment(config={"epochs": 40,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "sgd"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 40
#   lr: 0.001
#   batch_size: 32
#   optimizer: sgd
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 2.303 | Train acc: 0.100 | Val loss: 2.301 |  Val acc: 0.101
# Epoch: 2 | Train loss: 2.300 | Train acc: 0.107 | Val loss: 2.298 |  Val acc: 0.113
# Epoch: 3 | Train loss: 2.294 | Train acc: 0.113 | Val loss: 2.290 |  Val acc: 0.114
# Epoch: 4 | Train loss: 2.280 | Train acc: 0.172 | Val loss: 2.265 |  Val acc: 0.217
# Epoch: 5 | Train loss: 2.232 | Train acc: 0.206 | Val loss: 2.178 |  Val acc: 0.208
# Epoch: 6 | Train loss: 2.120 | Train acc: 0.232 | Val loss: 2.053 |  Val acc: 0.261
# Epoch: 7 | Train loss: 2.009 | Train acc: 0.276 | Val loss: 1.960 |  Val acc: 0.293
# Epoch: 8 | Train loss: 1.938 | Train acc: 0.298 | Val loss: 1.904 |  Val acc: 0.306
# Epoch: 9 | Train loss: 1.889 | Train acc: 0.314 | Val loss: 1.858 |  Val acc: 0.318
# ...

# %%
exp.plot_graphs()

# %% [markdown]
# # 4.1.4 Batch size
#
# All experiments here will be run with **learning rate = 0.001** and **epochs = 20**.

# %% [markdown]
# ## Batch size = 4

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 4,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 4
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.516 | Train acc: 0.447 | Val loss: 1.272 |  Val acc: 0.529
# Epoch: 2 | Train loss: 1.252 | Train acc: 0.555 | Val loss: 1.181 |  Val acc: 0.577
# Epoch: 3 | Train loss: 1.164 | Train acc: 0.588 | Val loss: 1.115 |  Val acc: 0.606
# Epoch: 4 | Train loss: 1.114 | Train acc: 0.609 | Val loss: 1.095 |  Val acc: 0.611
# Epoch: 5 | Train loss: 1.077 | Train acc: 0.621 | Val loss: 1.078 |  Val acc: 0.629
# Epoch: 6 | Train loss: 1.047 | Train acc: 0.633 | Val loss: 1.095 |  Val acc: 0.615
# Epoch: 7 | Train loss: 1.029 | Train acc: 0.639 | Val loss: 1.012 |  Val acc: 0.652
# Epoch: 8 | Train loss: 1.010 | Train acc: 0.648 | Val loss: 0.999 |  Val acc: 0.657
# Epoch: 9 | Train loss: 0.997 | Train acc: 0.653 | Val loss: 0.987 |  Val acc: 0.665
# ...

# %%
bs_4_accuracy = exp.val_acc[-1]

# %% [markdown]
# ## Batch size = 8

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 8,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 8
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.535 | Train acc: 0.435 | Val loss: 1.341 |  Val acc: 0.515
# Epoch: 2 | Train loss: 1.272 | Train acc: 0.541 | Val loss: 1.169 |  Val acc: 0.588
# Epoch: 3 | Train loss: 1.173 | Train acc: 0.580 | Val loss: 1.129 |  Val acc: 0.596
# Epoch: 4 | Train loss: 1.111 | Train acc: 0.605 | Val loss: 1.142 |  Val acc: 0.598
# Epoch: 5 | Train loss: 1.068 | Train acc: 0.621 | Val loss: 1.032 |  Val acc: 0.635
# Epoch: 6 | Train loss: 1.037 | Train acc: 0.632 | Val loss: 1.045 |  Val acc: 0.628
# Epoch: 7 | Train loss: 1.007 | Train acc: 0.644 | Val loss: 1.027 |  Val acc: 0.636
# Epoch: 8 | Train loss: 0.987 | Train acc: 0.653 | Val loss: 0.962 |  Val acc: 0.668
# Epoch: 9 | Train loss: 0.965 | Train acc: 0.660 | Val loss: 0.959 |  Val acc: 0.672
# ...

# %%
bs_8_accuracy = exp.val_acc[-1]

# %% [markdown]
# ## Batch size = 16

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 16,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 16
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.488 | Train acc: 0.454 | Val loss: 1.214 |  Val acc: 0.563
# Epoch: 2 | Train loss: 1.170 | Train acc: 0.583 | Val loss: 1.059 |  Val acc: 0.625
# Epoch: 3 | Train loss: 1.035 | Train acc: 0.635 | Val loss: 1.042 |  Val acc: 0.635
# Epoch: 4 | Train loss: 0.952 | Train acc: 0.663 | Val loss: 0.950 |  Val acc: 0.666
# Epoch: 5 | Train loss: 0.904 | Train acc: 0.683 | Val loss: 0.929 |  Val acc: 0.682
# Epoch: 6 | Train loss: 0.871 | Train acc: 0.697 | Val loss: 0.883 |  Val acc: 0.696
# Epoch: 7 | Train loss: 0.833 | Train acc: 0.707 | Val loss: 0.875 |  Val acc: 0.694
# Epoch: 8 | Train loss: 0.809 | Train acc: 0.717 | Val loss: 0.812 |  Val acc: 0.722
# Epoch: 9 | Train loss: 0.783 | Train acc: 0.725 | Val loss: 0.817 |  Val acc: 0.714
# ...

# %%
bs_16_accuracy = exp.val_acc[-1]

# %% [markdown]
# ## Batch size = 32

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 32
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.518 | Train acc: 0.441 | Val loss: 1.232 |  Val acc: 0.557
# Epoch: 2 | Train loss: 1.176 | Train acc: 0.583 | Val loss: 1.035 |  Val acc: 0.638
# Epoch: 3 | Train loss: 1.032 | Train acc: 0.634 | Val loss: 0.988 |  Val acc: 0.653
# Epoch: 4 | Train loss: 0.945 | Train acc: 0.665 | Val loss: 0.919 |  Val acc: 0.684
# Epoch: 5 | Train loss: 0.888 | Train acc: 0.688 | Val loss: 0.834 |  Val acc: 0.711
# Epoch: 6 | Train loss: 0.845 | Train acc: 0.703 | Val loss: 0.874 |  Val acc: 0.697
# Epoch: 7 | Train loss: 0.803 | Train acc: 0.717 | Val loss: 0.828 |  Val acc: 0.718
# Epoch: 8 | Train loss: 0.779 | Train acc: 0.726 | Val loss: 0.834 |  Val acc: 0.711
# Epoch: 9 | Train loss: 0.759 | Train acc: 0.736 | Val loss: 0.780 |  Val acc: 0.739
# ...

# %%
bs_32_accuracy = exp.val_acc[-1]

# %% [markdown]
# ## Plot of batch size vs validation accuracy

# %%
batch_size_accuracies = [bs_4_accuracy,bs_8_accuracy,bs_16_accuracy,bs_32_accuracy]
fig = plt.figure(figsize=(8,6))
plt.plot(np.arange(len(batch_size_accuracies)), batch_size_accuracies, "ro-")
plt.xlabel("Batch Size")
plt.ylabel("Validation Accuracy")
plt.xticks(np.arange(4), [4,8,16,32])
plt.title("Models trained for 20 epochs")
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# # Effect of Loss Function
#
# Using the KL Divergence Loss for this example.

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "adam",
                          "criterion": "kl_divergence"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 32
#   optimizer: adam
#   criterion: kl_divergence
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.550 | Train acc: 0.430 | Val loss: 1.313 |  Val acc: 0.528
# Epoch: 2 | Train loss: 1.202 | Train acc: 0.568 | Val loss: 1.120 |  Val acc: 0.599
# Epoch: 3 | Train loss: 1.071 | Train acc: 0.618 | Val loss: 1.027 |  Val acc: 0.639
# Epoch: 4 | Train loss: 0.996 | Train acc: 0.646 | Val loss: 0.939 |  Val acc: 0.669
# Epoch: 5 | Train loss: 0.941 | Train acc: 0.666 | Val loss: 0.943 |  Val acc: 0.668
# Epoch: 6 | Train loss: 0.895 | Train acc: 0.683 | Val loss: 0.878 |  Val acc: 0.695
# Epoch: 7 | Train loss: 0.866 | Train acc: 0.695 | Val loss: 0.855 |  Val acc: 0.701
# Epoch: 8 | Train loss: 0.838 | Train acc: 0.706 | Val loss: 0.846 |  Val acc: 0.709
# Epoch: 9 | Train loss: 0.816 | Train acc: 0.712 | Val loss: 0.846 |  Val acc: 0.701
# ...

# %%
exp.get_classwise_val_accuracy()
# Out:
# Classwise accuracies on validation set after epoch 20 -
# Accuracy for class: plane is 78.3 %
# Accuracy for class: car   is 86.0 %
# Accuracy for class: bird  is 58.2 %
# Accuracy for class: cat   is 59.4 %
# Accuracy for class: deer  is 74.3 %
# Accuracy for class: dog   is 63.3 %
# Accuracy for class: frog  is 77.7 %
# Accuracy for class: horse is 75.1 %
# Accuracy for class: ship  is 87.4 %
# Accuracy for class: truck is 84.8 %

# %%
exp.plot_graphs()

# %%
# original nn cross entropy experiment 
exp1.plot_graphs()

# %% [markdown]
# **Observation:** KL divergence loss also performs similar to crossentropy

# %% [markdown]
# # 4.3 Effect of Data Augmentation
#
# Here I removed all the data augmentation including the previously added random horizontal flip and random rotation. Need to create the datasets again then with the new transforms.

# %%
# Define transforms WITHOUT data augmentation
transform =  transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# Get train and test dataloaders
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

valset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
exp = Experiment(config={"epochs": 20,
                          "lr": 0.001,
                          "batch_size": 32,
                          "optimizer": "adam"})
exp.run_experiment()
# Out:
# Running experiment with -
#   epochs: 20
#   lr: 0.001
#   batch_size: 32
#   optimizer: adam
#   criterion: cross_entropy
#   lr_scheduler: False
# ----------------------------
# Epoch: 1 | Train loss: 1.519 | Train acc: 0.439 | Val loss: 1.308 |  Val acc: 0.523
# Epoch: 2 | Train loss: 1.148 | Train acc: 0.592 | Val loss: 1.057 |  Val acc: 0.628
# Epoch: 3 | Train loss: 0.987 | Train acc: 0.650 | Val loss: 0.966 |  Val acc: 0.656
# Epoch: 4 | Train loss: 0.878 | Train acc: 0.690 | Val loss: 0.901 |  Val acc: 0.688
# Epoch: 5 | Train loss: 0.801 | Train acc: 0.717 | Val loss: 0.868 |  Val acc: 0.704
# Epoch: 6 | Train loss: 0.743 | Train acc: 0.738 | Val loss: 0.879 |  Val acc: 0.700
# Epoch: 7 | Train loss: 0.693 | Train acc: 0.756 | Val loss: 0.837 |  Val acc: 0.718
# Epoch: 8 | Train loss: 0.649 | Train acc: 0.772 | Val loss: 0.870 |  Val acc: 0.709
# Epoch: 9 | Train loss: 0.610 | Train acc: 0.785 | Val loss: 0.819 |  Val acc: 0.724
# ...

# %%
exp.plot_graphs()

# %% [markdown]
# **Observation:** Training accuracy will be better without data augmentation as can be seen ~0.88. Data augemntation helps the model to generalize better on unseen images, without it the model might start memorizing the training data and perform worse on slight deviations from the training distribution when encountering unseen images.

# %% [markdown]
# ---
